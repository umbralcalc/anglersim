# %%
import sys
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

path = "/home/robert/Code/ecochange/"

sys.path.append(path)
from src.data.database import ecoDB
import src.data.gov_data_utils as datutils

# %%
edb = ecoDB(path)
edb.get_unzipped_files("GB_SAC_shape_file")
df = gpd.read_file("data/" + edb.unzipped_files["GB_SAC_shape_file"][0])

# Plot the colourmap
fig, ax = plt.subplots(1, 1, figsize=(20, 20))
df.plot(ax=ax)
ax.set_xticks([])
ax.set_yticks([])
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show()
# Out:
# Archive:  GB_SAC_shape_file.zip
#   inflating: GB_SAC_OSGB36_20191031.shp
#   inflating: GB_SAC_OSGB36_20191031.shx
